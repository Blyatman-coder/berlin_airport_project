# %% [markdown]
# # We are going to write a script that will web scrape the latest data analytics positions from LinkedIn in a Location we choose:

# %% [markdown]
# ---

# %% [markdown]
# ### Import every library ever created

# %%
# this is the library that we will use to create break times in order to mimic human behaviour
import time
from getpass import getpass


# Juicy stuff- these are the Classes we will use for interaction with a webpage:
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager


# library for interacting with the operating system
import os

# you know pandas it's your best buddy
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import re

# library for directory location:

import pathlib
import os
from os.path import join

#Ignore warning -- Some methods are going to be deprecated and I didn't change all (mainly in the function scrapper)
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Load a driver and the website

# %%
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))

# %%
driver.get('https://ber.berlin-airport.de/en/flying/departures-arrivals.html?date=2024-06-27&flightType=D&search=')

# %% [markdown]
# ### Click cookies

# %%
try:
    cookie_button = driver.find_element(By.ID, "CybotCookiebotDialogBodyLevelButtonLevelOptinAllowAll")
    cookie_button.click()
    time.sleep(2.5)
except:
    print("Cookies already accepted.")

# %% [markdown]
# ### Try scroll to the end

# %%
page = driver.find_element(By.CSS_SELECTOR, "body[class^='page basicpage']")
page.click()
time.sleep(1)

flight_viewer = driver.find_element(By.CSS_SELECTOR, "body[class^='page basicpage']") #page = driver.find_element_by_css_selector("a[class^='disabled ember-view']")
flight_viewer.send_keys(Keys.END)

# %% [markdown]
# ### Click load more as many times until all flights are listed

# %%
load_more = driver.find_element(By.CLASS_NAME, "cmp-flightlist__action-link")
load_more.click()

# %% [markdown]
# ### Get the html page source

# %%
html = driver.page_source
soup = BeautifulSoup(html)

# %% [markdown]
# ### Get all the flight links and save to a list

# %%
flights = soup.find_all('div', attrs= {'class' : 'cmp-flightlist__list__items'})
result_set_html = ''.join(str(tag) for tag in flights)
new_flights = BeautifulSoup(result_set_html, 'html.parser')
base_url = "https://ber.berlin-airport.de"
a_tags = new_flights.find_all('a')
href_list = [base_url + tag['href'] for tag in a_tags if 'href' in tag.attrs]

# %% [markdown]
# ### Save the links to a file for safe keeps

# %%
date_of_scrape = input("What Day: ")
arr_dep = input("Arrival or Departure: ")
file_path = f"/Users/martynas/Desktop/Ironhack/Week 9:Selenium/Berlin Scraper/Href Links/{arr_dep}_links_{date_of_scrape}.txt"

with open(file_path, 'w') as file:
    for href in href_list:
        file.write(f"{href}\n")
# Out:
# What Day: 27
# Arrival or Departure: arrival

# %% [markdown]
# ### Open the links file into a list

# %%
with open('/Users/martynas/Desktop/Ironhack/Week 9:Selenium/Berlin Scraper/Href Links/departure_links_27.txt', 'r') as file:
    href_list_dep = [line.strip() for line in file]

# %%
with open('/Users/martynas/Desktop/Ironhack/Week 9:Selenium/Berlin Scraper/Href Links/arrival_links_24.txt', 'r') as file:
    href_list_arr = [line.strip() for line in file]

# %% [markdown]
# ### Test for elements

# %%
driver.get(href_list_dep[154])

# %%
href_list_dep[0]
# Out:
# 'https://ber.berlin-airport.de/en/flying/departures-arrivals/flugdetails.html?flightId=1248683'

# %%
href_list_arr[0]
# Out:
# 'https://ber.berlin-airport.de/en/flying/departures-arrivals/flugdetails.html?flightId=1248662'

# %%
new_element = driver.find_element(By.CSS_SELECTOR,"strong[data-flight-data^='dep_expected_time']").text

# %%
new_element
# Out:
# '18/06/2024 13:00'

# %% [markdown]
# ## Run to create a database

# %% [markdown]
# ### Departures

# %%
flight_data_dep = []
date_of_scrape = input("What Day: ")
for_loading = 0

with open(f"/Users/martynas/Desktop/Ironhack/Week 9:Selenium/Berlin Scraper/Href Links/departure_links_{date_of_scrape}.txt", 'r') as file:
    href_list_dep = [line.strip() for line in file]

for link in href_list_dep:
    
    driver.get(link)
    time.sleep(1)
    
    try:
        cookie_button = driver.find_element(By.ID, "CybotCookiebotDialogBodyLevelButtonLevelOptinAllowAll")
        cookie_button.click()
        time.sleep(1.5)
    except:
        pass
    
    driver.execute_script("document.body.style.zoom='100%'")

    driver.execute_script("document.body.style.zoom='67%'")
    time.sleep(1.3)
    
    
    depart_air = driver.find_element(By.CSS_SELECTOR,"h2[data-flight-data^='dep_airport_name']").text
    arrival_air = driver.find_element(By.CSS_SELECTOR,"h2[data-flight-data^='arr_airport_name']").text
    date_time = driver.find_element(By.CSS_SELECTOR,"strong[data-flight-data^='dep_scheduled_time']").text
    actual_time = driver.find_element(By.CSS_SELECTOR,"strong[data-flight-data^='dep_expected_time']").text
    terminal = driver.find_element(By.CSS_SELECTOR,"i[data-flight-data^='terminal']").text
    check_in = driver.find_element(By.CSS_SELECTOR,"strong[data-flight-data^='checkin_counter']").text
    gate = driver.find_element(By.CSS_SELECTOR,"strong[data-flight-data^='gate']").text
    airline = driver.find_element(By.CSS_SELECTOR,"span[data-flight-data^='airline_name']").text
    flight_nr = driver.find_element(By.CSS_SELECTOR,"strong[data-flight-data^='flight_number_details']").text
    aircraft_type = driver.find_element(By.CSS_SELECTOR,"strong[data-flight-data^='aircraft_type']").text
    plane_reg = driver.find_element(By.CSS_SELECTOR,"strong[data-flight-data^='aircraft_reg']").text
    status = driver.find_element(By.CSS_SELECTOR,"u[data-flight-data^='flight_status_label']").text

    flight_idx_list_dep = [depart_air, arrival_air, date_time, actual_time, terminal, check_in, gate, flight_nr, aircraft_type, plane_reg, status, airline]
    
    flight_data_dep.append(flight_idx_list_dep)
    
    
    for_loading = for_loading+1
    print(f"{for_loading} out of {len(href_list_dep)} scraped")
    
departure_dataframe = pd.DataFrame(flight_data_dep,
                                 columns = ["Departure", "Destination", "Date and Time", "Actual Departure", "Terminal", "Check In" , "Gate", "Flight Number", "Aircraft Type", "Plane Reg", "Flight Status", "Airline" ]
                                )

departure_dataframe.to_excel(f"/Users/martynas/Desktop/Ironhack/Week 9:Selenium/Berlin Scraper/Data/departure_info_{date_of_scrape}.xlsx",
                           sheet_name='Flights',
                           index= False)
# Out:
# What Day: 27
# 1 out of 270 scraped
# 2 out of 270 scraped
# 3 out of 270 scraped
# 4 out of 270 scraped
# 5 out of 270 scraped
# 6 out of 270 scraped
# 7 out of 270 scraped
# 8 out of 270 scraped
# 9 out of 270 scraped
# 10 out of 270 scraped
# 11 out of 270 scraped
# 12 out of 270 scraped
# 13 out of 270 scraped
# 14 out of 270 scraped
# 15 out of 270 scraped
# 16 out of 270 scraped
# 17 out of 270 scraped
# 18 out of 270 scraped
# 19 out of 270 scraped
# 20 out of 270 scraped
# 21 out of 270 scraped
# 22 out of 270 scraped
# 23 out of 270 scraped
# 24 out of 270 scraped
# 25 out of 270 scraped
# 26 out of 270 scraped
# 27 out of 270 scraped
# 28 out of 270 scraped
# 29 out of 270 scraped
# 30 out of 270 scraped
# 31 out of 270 scraped
# 32 out of 270 scraped
# 33 out of 270 scraped
# 34 out of 270 scraped
# 35 out of 270 scraped
# 36 out of 270 scraped
# 37 out of 270 scraped
# 38 out of 270 scraped
# 39 out of 270 scraped
# 40 out of 270 scraped
# 41 out of 270 scraped
# 42 out of 270 scraped
# 43 out of 270 scraped
# 44 out of 270 scraped
# 45 out of 270 scraped
# 46 out of 270 scraped
# 47 out of 270 scraped
# 48 out of 270 scraped
# 49 out of 270 scraped
# 50 out of 270 scraped
# 51 out of 270 scraped
# 52 out of 270 scraped
# 53 out of 270 scraped
# 54 out of 270 scraped
# 55 out of 270 scraped
# 56 out of 270 scraped
# 57 out of 270 scraped
# 58 out of 270 scraped
# 59 out of 270 scraped
# 60 out of 270 scraped
# 61 out of 270 scraped
# 62 out of 270 scraped
# 63 out of 270 scraped
# 64 out of 270 scraped
# 65 out of 270 scraped
# 66 out of 270 scraped
# 67 out of 270 scraped
# 68 out of 270 scraped
# 69 out of 270 scraped
# 70 out of 270 scraped
# 71 out of 270 scraped
# 72 out of 270 scraped
# 73 out of 270 scraped
# 74 out of 270 scraped
# 75 out of 270 scraped
# 76 out of 270 scraped
# 77 out of 270 scraped
# 78 out of 270 scraped
# 79 out of 270 scraped
# 80 out of 270 scraped
# 81 out of 270 scraped
# 82 out of 270 scraped
# 83 out of 270 scraped
# 84 out of 270 scraped
# 85 out of 270 scraped
# 86 out of 270 scraped
# 87 out of 270 scraped
# 88 out of 270 scraped
# 89 out of 270 scraped
# 90 out of 270 scraped
# 91 out of 270 scraped
# 92 out of 270 scraped
# 93 out of 270 scraped
# 94 out of 270 scraped
# 95 out of 270 scraped
# 96 out of 270 scraped
# 97 out of 270 scraped
# 98 out of 270 scraped
# 99 out of 270 scraped
# 100 out of 270 scraped
# 101 out of 270 scraped
# 102 out of 270 scraped
# 103 out of 270 scraped
# 104 out of 270 scraped
# 105 out of 270 scraped
# 106 out of 270 scraped
# 107 out of 270 scraped
# 108 out of 270 scraped
# 109 out of 270 scraped
# 110 out of 270 scraped
# 111 out of 270 scraped
# 112 out of 270 scraped
# 113 out of 270 scraped
# 114 out of 270 scraped
# 115 out of 270 scraped
# 116 out of 270 scraped
# 117 out of 270 scraped
# 118 out of 270 scraped
# 119 out of 270 scraped
# 120 out of 270 scraped
# 121 out of 270 scraped
# 122 out of 270 scraped
# 123 out of 270 scraped
# 124 out of 270 scraped
# 125 out of 270 scraped
# 126 out of 270 scraped
# 127 out of 270 scraped
# 128 out of 270 scraped
# 129 out of 270 scraped
# 130 out of 270 scraped
# 131 out of 270 scraped
# 132 out of 270 scraped
# 133 out of 270 scraped
# 134 out of 270 scraped
# 135 out of 270 scraped
# 136 out of 270 scraped
# 137 out of 270 scraped
# 138 out of 270 scraped
# 139 out of 270 scraped
# 140 out of 270 scraped
# 141 out of 270 scraped
# 142 out of 270 scraped
# 143 out of 270 scraped
# 144 out of 270 scraped
# 145 out of 270 scraped
# 146 out of 270 scraped
# 147 out of 270 scraped
# 148 out of 270 scraped
# 149 out of 270 scraped
# 150 out of 270 scraped
# 151 out of 270 scraped
# 152 out of 270 scraped
# 153 out of 270 scraped
# 154 out of 270 scraped
# 155 out of 270 scraped
# 156 out of 270 scraped
# 157 out of 270 scraped
# 158 out of 270 scraped
# 159 out of 270 scraped
# 160 out of 270 scraped
# 161 out of 270 scraped
# 162 out of 270 scraped
# 163 out of 270 scraped
# 164 out of 270 scraped
# 165 out of 270 scraped
# 166 out of 270 scraped
# 167 out of 270 scraped
# 168 out of 270 scraped
# 169 out of 270 scraped
# 170 out of 270 scraped
# 171 out of 270 scraped
# 172 out of 270 scraped
# 173 out of 270 scraped
# 174 out of 270 scraped
# 175 out of 270 scraped
# 176 out of 270 scraped
# 177 out of 270 scraped
# 178 out of 270 scraped
# 179 out of 270 scraped
# 180 out of 270 scraped
# 181 out of 270 scraped
# 182 out of 270 scraped
# 183 out of 270 scraped
# 184 out of 270 scraped
# 185 out of 270 scraped
# 186 out of 270 scraped
# 187 out of 270 scraped
# 188 out of 270 scraped
# 189 out of 270 scraped
# 190 out of 270 scraped
# 191 out of 270 scraped
# 192 out of 270 scraped
# 193 out of 270 scraped
# 194 out of 270 scraped
# 195 out of 270 scraped
# 196 out of 270 scraped
# 197 out of 270 scraped
# 198 out of 270 scraped
# 199 out of 270 scraped
# 200 out of 270 scraped
# 201 out of 270 scraped
# 202 out of 270 scraped
# 203 out of 270 scraped
# 204 out of 270 scraped
# 205 out of 270 scraped
# 206 out of 270 scraped
# 207 out of 270 scraped
# 208 out of 270 scraped
# 209 out of 270 scraped
# 210 out of 270 scraped
# 211 out of 270 scraped
# 212 out of 270 scraped
# 213 out of 270 scraped
# 214 out of 270 scraped
# 215 out of 270 scraped
# 216 out of 270 scraped
# 217 out of 270 scraped
# 218 out of 270 scraped
# 219 out of 270 scraped
# 220 out of 270 scraped
# 221 out of 270 scraped
# 222 out of 270 scraped
# 223 out of 270 scraped
# 224 out of 270 scraped
# 225 out of 270 scraped
# 226 out of 270 scraped
# 227 out of 270 scraped
# 228 out of 270 scraped
# 229 out of 270 scraped
# 230 out of 270 scraped
# 231 out of 270 scraped
# 232 out of 270 scraped
# 233 out of 270 scraped
# 234 out of 270 scraped
# 235 out of 270 scraped
# 236 out of 270 scraped
# 237 out of 270 scraped
# 238 out of 270 scraped
# 239 out of 270 scraped
# 240 out of 270 scraped
# 241 out of 270 scraped
# 242 out of 270 scraped
# 243 out of 270 scraped
# 244 out of 270 scraped
# 245 out of 270 scraped
# 246 out of 270 scraped
# 247 out of 270 scraped
# 248 out of 270 scraped
# 249 out of 270 scraped
# 250 out of 270 scraped
# 251 out of 270 scraped
# 252 out of 270 scraped
# 253 out of 270 scraped
# 254 out of 270 scraped
# 255 out of 270 scraped
# 256 out of 270 scraped
# 257 out of 270 scraped
# 258 out of 270 scraped
# 259 out of 270 scraped
# 260 out of 270 scraped
# 261 out of 270 scraped
# 262 out of 270 scraped
# 263 out of 270 scraped
# 264 out of 270 scraped
# 265 out of 270 scraped
# 266 out of 270 scraped
# 267 out of 270 scraped
# 268 out of 270 scraped
# 269 out of 270 scraped
# 270 out of 270 scraped

# %%
flight_data_arr = []
date_of_scrape = input("What Date: ")
for_loading = 0

with open(f"/Users/martynas/Desktop/Ironhack/Week 9:Selenium/Berlin Scraper/Href Links/arrival_links_{date_of_scrape}.txt", 'r') as file:
    href_list_arr = [line.strip() for line in file]

for link in href_list_arr[:4]:
    
    driver.get(link)
    time.sleep(1)
    
    try:
        cookie_button = driver.find_element(By.ID, "CybotCookiebotDialogBodyLevelButtonLevelOptinAllowAll")
        cookie_button.click()
        time.sleep(1.5)
    except:
        pass
    
    driver.execute_script("document.body.style.zoom='100%'")

    driver.execute_script("document.body.style.zoom='67%'")
    time.sleep(1.3)
    
    
    depart_air = driver.find_element(By.CSS_SELECTOR,"h2[data-flight-data^='dep_airport_name']").text
    arrival_air = driver.find_element(By.CSS_SELECTOR,"h2[data-flight-data^='arr_airport_name']").text
    date_time = driver.find_element(By.CSS_SELECTOR,"strong[data-flight-data^='arr_scheduled_time']").text
    actual_time = driver.find_element(By.CSS_SELECTOR,"strong[data-flight-data^='arr_expected_time']").text
    terminal = driver.find_element(By.CSS_SELECTOR,"i[data-flight-data^='terminal_arr']").text
    check_in = driver.find_element(By.CSS_SELECTOR,"strong[data-flight-data^='arr_belt']").text
    gate = driver.find_element(By.CSS_SELECTOR,"strong[data-flight-data^='gate_arr']").text
    airline = driver.find_element(By.CSS_SELECTOR,"span[data-flight-data^='airline_name']").text
    flight_nr = driver.find_element(By.CSS_SELECTOR,"strong[data-flight-data^='flight_number_details']").text
    aircraft_type = driver.find_element(By.CSS_SELECTOR,"strong[data-flight-data^='aircraft_type']").text
    plane_reg = driver.find_element(By.CSS_SELECTOR,"strong[data-flight-data^='aircraft_reg']").text
    status = driver.find_element(By.CSS_SELECTOR,"u[data-flight-data^='flight_status_label']").text

    flight_idx_list_arr = [depart_air, arrival_air, date_time, actual_time, terminal, check_in, gate, flight_nr, aircraft_type, plane_reg, status, airline]
    
    flight_data_arr.append(flight_idx_list_arr)
    
    
    for_loading = for_loading+1
    print(f"{for_loading} out of {len(href_list_arr)} scraped")
    
arrival_dataframe = pd.DataFrame(flight_data_arr,
                                 columns = ["Departure", "Destination", "Date and Time", "Actual Arrival", "Terminal", "Baggage Claim" , "Gate", "Flight Number", "Aircraft Type", "Plane Reg", "Flight Status", "Airline" ]
                                )

arrival_dataframe.to_excel(f"/Users/martynas/Desktop/Ironhack/Week 9:Selenium/Berlin Scraper/Data/arrival_info_{date_of_scrape}.xlsx",
                           sheet_name='Flights',
                           index= False)
# Out:
# What Date: 18
# 1 out of 268 scraped
# 2 out of 268 scraped
# 3 out of 268 scraped
# 4 out of 268 scraped

# %% [markdown]
# ### Close Driver

# %%
driver.close()

# %% [markdown]
# ---

# %% [markdown]
# ### Combining and Cleaning the dataframes

# %% [markdown]
# #### Arrivals

# %%
df_arr1 = pd.read_excel('/Users/martynas/Desktop/Ironhack/Week 9:Selenium/Berlin Scraper/Data/arrival_info_16.xlsx')
df_arr2 = pd.read_excel('/Users/martynas/Desktop/Ironhack/Week 9:Selenium/Berlin Scraper/Data/arrival_info_17.xlsx')
df_arr3 = pd.read_excel('/Users/martynas/Desktop/Ironhack/Week 9:Selenium/Berlin Scraper/Data/arrival_info_18.xlsx')
df_arr4 = pd.read_excel('/Users/martynas/Desktop/Ironhack/Week 9:Selenium/Berlin Scraper/Data/arrival_info_24.xlsx')
df_arr5 = pd.read_excel('/Users/martynas/Desktop/Ironhack/Week 9:Selenium/Berlin Scraper/Data/arrival_info_25.xlsx')
df_arr6 = pd.read_excel('/Users/martynas/Desktop/Ironhack/Week 9:Selenium/Berlin Scraper/Data/arrival_info_26.xlsx')
df_arr7 = pd.read_excel('/Users/martynas/Desktop/Ironhack/Week 9:Selenium/Berlin Scraper/Data/arrival_info_27.xlsx')

# %%
combined_df_arr = pd.concat([df_arr1,df_arr2,df_arr3,df_arr4,df_arr5,df_arr6,df_arr7], ignore_index=True)

# %%
combined_df_arr['Destination'] = combined_df_arr['Destination'].replace('Berlin Brandenburg Airport', 'Berlin')
combined_df_arr[['Date', 'Scheduled Time']] = combined_df_arr['Date and Time'].str.split(' ', expand=True)
combined_df_arr[['Date Schedule', 'Actual Arrival Time']] = combined_df_arr['Actual Arrival'].str.split(' ', expand=True)
combined_df_arr.drop(columns=['Date and Time'], inplace=True)
combined_df_arr.drop(columns=['Date Schedule'], inplace=True)
combined_df_arr.drop(columns=['Actual Arrival'], inplace=True)
combined_df_arr['Terminal'] = combined_df_arr['Terminal'].str.replace('T', '')
combined_df_arr = combined_df_arr[combined_df_arr['Baggage Claim'] != '##']
combined_df_arr['Terminal'] = combined_df_arr['Terminal'].astype('Int64')
combined_df_arr['Date'] = pd.to_datetime(combined_df_arr['Date'], dayfirst=True)
conditions = [(combined_df_arr['Actual Arrival Time'].isnull()) | (combined_df_arr['Scheduled Time'] == combined_df_arr['Actual Arrival Time']), combined_df_arr['Scheduled Time'] < combined_df_arr['Actual Arrival Time'],combined_df_arr['Scheduled Time'] > combined_df_arr['Actual Arrival Time']]
choices = ['On-Time', 'Delayed', 'Early']
combined_df_arr['Status'] = np.select(conditions, choices, default='Unknown')

# %%
combined_df_arr.shape
# Out:
# (1863, 14)

# %%
combined_file = 'arrivals_june.xlsx'
combined_df_arr.to_excel(combined_file, index=False)

# %% [markdown]
# #### Departures

# %%
df_dep1 = pd.read_excel('/Users/martynas/Desktop/Ironhack/Week 9:Selenium/Berlin Scraper/Data/departure_info_16.xlsx')
df_dep2 = pd.read_excel('/Users/martynas/Desktop/Ironhack/Week 9:Selenium/Berlin Scraper/Data/departure_info_17.xlsx')
df_dep3 = pd.read_excel('/Users/martynas/Desktop/Ironhack/Week 9:Selenium/Berlin Scraper/Data/departure_info_18.xlsx')
df_dep4 = pd.read_excel('/Users/martynas/Desktop/Ironhack/Week 9:Selenium/Berlin Scraper/Data/departure_info_24.xlsx')
df_dep5 = pd.read_excel('/Users/martynas/Desktop/Ironhack/Week 9:Selenium/Berlin Scraper/Data/departure_info_25.xlsx')
df_dep6 = pd.read_excel('/Users/martynas/Desktop/Ironhack/Week 9:Selenium/Berlin Scraper/Data/departure_info_26.xlsx')
df_dep7 = pd.read_excel('/Users/martynas/Desktop/Ironhack/Week 9:Selenium/Berlin Scraper/Data/departure_info_27.xlsx')

# %%
combined_df_dep = pd.concat([df_dep1,df_dep2,df_dep3,df_dep4,df_dep5,df_dep6,df_dep7], ignore_index=True)

# %%
combined_df_dep['Departure'] = combined_df_dep['Departure'].replace('Berlin Brandenburg Airport', 'Berlin')
combined_df_dep[['Date', 'Scheduled Time']] = combined_df_dep['Date and Time'].str.split(' ', expand=True)
combined_df_dep[['Date Schedule', 'Actual Departure Time']] = combined_df_dep['Actual Departure'].str.split(' ', expand=True)
combined_df_dep.drop(columns=['Date and Time'], inplace=True)
combined_df_dep.drop(columns=['Date Schedule'], inplace=True)
combined_df_dep.drop(columns=['Actual Departure'], inplace=True)
combined_df_dep['Terminal'] = combined_df_dep['Terminal'].str.replace('T', '')
combined_df_dep = combined_df_dep[combined_df_dep['Check In'] != '##']
combined_df_dep = combined_df_dep[combined_df_dep['Terminal'] != '##']
combined_df_dep['Terminal'] = combined_df_dep['Terminal'].astype('Int64')
combined_df_dep['Date'] = pd.to_datetime(combined_df_dep['Date'], dayfirst=True)
conditions = [(combined_df_dep['Actual Departure Time'].isnull()) | (combined_df_dep['Scheduled Time'] == combined_df_dep['Actual Departure Time']), combined_df_dep['Scheduled Time'] < combined_df_dep['Actual Departure Time'],combined_df_dep['Scheduled Time'] > combined_df_dep['Actual Departure Time']]
choices = ['On-Time', 'Delayed', 'Early']
combined_df_dep['Status'] = np.select(conditions, choices, default='Unknown')

# %%
combined_df_dep.shape
# Out:
# (1868, 14)

# %%
combined_file = 'departures_june.xlsx'
combined_df_dep.to_excel(combined_file, index=False)

# %% [markdown]
# ---

# %%
golden_arr = pd.read_excel('/Users/martynas/Desktop/Ironhack/Week 9:Selenium/Berlin Scraper/GOLDEN TABLES/arrivals_june.xlsx')

# %%
golden_dep = pd.read_excel('/Users/martynas/Desktop/Ironhack/Week 9:Selenium/Berlin Scraper/GOLDEN TABLES/departures_june.xlsx')

# %%
df_arr3
# Out:
#                       Departure        Destination Date and Time  \
# 0    Berlin Brandenburg Airport  Palma de Mallorca           NaN
# 1    Berlin Brandenburg Airport              Ibiza           NaN
# 2    Berlin Brandenburg Airport  Palma de Mallorca           NaN
# 3    Berlin Brandenburg Airport             Zurich           NaN
# 4    Berlin Brandenburg Airport  Palma de Mallorca           NaN
# ..                          ...                ...           ...
# 263  Berlin Brandenburg Airport         Diyarbakir           NaN
# 264  Berlin Brandenburg Airport               Pisa           NaN
# 265  Berlin Brandenburg Airport             Tirana           NaN
# 266  Berlin Brandenburg Airport     Nottingham EMA           NaN
# 267  Berlin Brandenburg Airport          Barcelona           NaN
#
#     Actual Arrival Terminal Baggage Claim Gate Flight Number  \
# 0              NaN      NaN           NaN  NaN       SR 2412
# 1              NaN      NaN           NaN  NaN       EW 8540
# 2              NaN      NaN           NaN  NaN       EJU5119
# 3              NaN      NaN           NaN  NaN       EJU5187
# 4              NaN      NaN           NaN  NaN        FR 110
# ..             ...      ...           ...  ...           ...
# 263            NaN      NaN           NaN  NaN       XQ 1701
# 264            NaN      NaN           NaN  NaN       FR 9956
# 265            NaN      NaN           NaN  NaN       W4 5106
# 266            NaN      NaN           NaN  NaN       FR 1639
# 267            NaN      NaN           NaN  NaN       VY 1885
#
#           Aircraft Type Plane Reg Flight Status                       Airline
# 0              A320-200     DASGK      Departed                 SUNDAIR (SDR)
# 1              A321 neo     DAEEC      Departed                Eurowings (EW)
# 2    A320-200 Sharklets     OEIDU      Departed          easyJet Europe (EJU)
# 3                  A319     OELKV      Departed          easyJet Europe (EJU)
# 4      737-800 Winglets     9HQAB      Departed                  Ryanair (FR)
# ..                  ...       ...           ...                           ...
# 263    737-800 Winglets     TCSPU      Departed              Sun Express (XQ)
# 264    737-800 Winglets     9HQFE      Departed                  Ryanair (FR)
# 265  A321-200 Sharklets     HALXC      Departed  Aero Services Executive (W4)
# 266    737-800 Winglets     EIEXD      Departed                  Ryanair (FR)
# 267  A321-200 Sharklets     ECMQL      Departed         Vueling Airlines (VY)
#
# [268 rows x 12 columns]

# %%
combined_df_arr
# Out:
#           Departure                 Destination     Date and Time  \
# 0         Izmir ADB  Berlin Brandenburg Airport  16/06/2024 06:30
# 1           Beijing  Berlin Brandenburg Airport  16/06/2024 06:45
# 2      New York EWR  Berlin Brandenburg Airport  16/06/2024 07:15
# 3          Chisinau  Berlin Brandenburg Airport  16/06/2024 07:20
# 4              Doha  Berlin Brandenburg Airport  16/06/2024 07:20
# ...             ...                         ...               ...
# 1871         Zurich  Berlin Brandenburg Airport  27/06/2024 22:55
# 1872     Manchester  Berlin Brandenburg Airport  27/06/2024 23:00
# 1873         Madrid  Berlin Brandenburg Airport  27/06/2024 23:00
# 1874     Paris Orly  Berlin Brandenburg Airport  27/06/2024 23:10
# 1875  Fuerteventura  Berlin Brandenburg Airport  27/06/2024 23:25
#
#         Actual Arrival Terminal Baggage Claim Gate Flight Number  \
# 0     16/06/2024 06:03       T1            A4  N02        XQ 966
# 1     16/06/2024 07:11       T1            A3  X17        HU 489
# 2     16/06/2024 07:07       T1            A2  Y17        UA 962
# 3     16/06/2024 08:17       T1            A1  X01        5F 611
# 4     16/06/2024 07:21       T1            A4  X07        QR 079
# ...                ...      ...           ...  ...           ...
# 1871               NaN       T1            A4  A03        LX 962
# 1872               NaN       T2            C1  Z43       FR 1155
# 1873               NaN       T1            A3  A30       I2 3674
# 1874               NaN       T1            B4  N01       TO 3412
# 1875               NaN       T1            B3  S01       SR 3345
#
#          Aircraft Type Plane Reg Flight Status                Airline
# 0     737-800 Winglets     TCSUU       Arrived       Sun Express (XQ)
# 1             A330-300     B303C       Arrived   Hainan Airlines (HU)
# 2        767-400/400ER    N76062       Arrived   United Airlines (UA)
# 3     737-800 Winglets     URPSF       Arrived          Fly One (FIA)
# 4     787-9 Dreamliner     A7BHM       Arrived     Qatar Airways (QR)
# ...                ...       ...           ...                    ...
# 1871          A321-100     HBIOD     Scheduled             Swiss (LX)
# 1872         737 MAX 8     9HVUZ     Scheduled           Ryanair (FR)
# 1873          A321-100       NaN     Scheduled   IBERIA Express (IBS)
# 1874  737-800 Winglets       NaN     Scheduled  Transavia France (TO)
# 1875          A320-200     DASGK     Scheduled          SUNDAIR (SDR)
#
# [1876 rows x 12 columns]

# %%
combined_df_dep
# Out:
#                        Departure        Destination     Date and Time  \
# 0     Berlin Brandenburg Airport              Porto  16/06/2024 05:20
# 1     Berlin Brandenburg Airport             Malaga  16/06/2024 05:40
# 2     Berlin Brandenburg Airport              Ibiza  16/06/2024 05:55
# 3     Berlin Brandenburg Airport             Malaga  16/06/2024 06:00
# 4     Berlin Brandenburg Airport  Palma de Mallorca  16/06/2024 06:00
# ...                          ...                ...               ...
# 1865  Berlin Brandenburg Airport              Basel  27/06/2024 22:00
# 1866  Berlin Brandenburg Airport  Palma de Mallorca  27/06/2024 22:00
# 1867  Berlin Brandenburg Airport          Barcelona  27/06/2024 22:05
# 1868  Berlin Brandenburg Airport         Copenhagen  27/06/2024 22:15
# 1869  Berlin Brandenburg Airport           Budapest  27/06/2024 22:30
#
#      Actual Departure Terminal Check In Gate Flight Number  \
# 0                 NaN       T1  323-326  A37       EW 8600
# 1                 NaN       T1  323-326  B07       EW 8536
# 2                 NaN       T1  323-326  A32       EW 8540
# 3                 NaN       T1  611-616  A30       EJU5105
# 4                 NaN       T1  611-616  A24       EJU5119
# ...               ...      ...      ...  ...           ...
# 1865              NaN       T1  611-616  NaN       EZS1190
# 1866              NaN       T2  158-165  NaN        FR 264
# 1867              NaN       T2  150-151  NaN       VY 1885
# 1868              NaN       T1      NaN  NaN       D8 3301
# 1869              NaN       T2  158-165  NaN        FR 196
#
#            Aircraft Type Plane Reg Flight Status                   Airline
# 0                   A319     DAGWH      Departed            Eurowings (EW)
# 1               A321 neo     DAEEC      Departed            Eurowings (EW)
# 2               A321-200     DAIDP      Departed            Eurowings (EW)
# 3     A320-200 Sharklets     OEIBF      Departed      easyJet Europe (EJU)
# 4     A320-200 Sharklets     OEING      Departed      easyJet Europe (EJU)
# ...                  ...       ...           ...                       ...
# 1865            A320 Neo     HBAYM     Scheduled  easyJet Switzerland (DS)
# 1866           737 MAX 8     EIIHY     Scheduled              Ryanair (FR)
# 1867            A321-100       NaN     Scheduled     Vueling Airlines (VY)
# 1868           737 MAX 8     SERTD     Scheduled        Norwegian Air (D8)
# 1869    737-800 Winglets     SPRSU     Scheduled              Ryanair (FR)
#
# [1870 rows x 12 columns]

# %%
combined_df_arr
# Out:
#           Departure                 Destination     Date and Time  \
# 0         Izmir ADB  Berlin Brandenburg Airport  16/06/2024 06:30
# 1           Beijing  Berlin Brandenburg Airport  16/06/2024 06:45
# 2      New York EWR  Berlin Brandenburg Airport  16/06/2024 07:15
# 3          Chisinau  Berlin Brandenburg Airport  16/06/2024 07:20
# 4              Doha  Berlin Brandenburg Airport  16/06/2024 07:20
# ...             ...                         ...               ...
# 1871         Zurich  Berlin Brandenburg Airport  27/06/2024 22:55
# 1872     Manchester  Berlin Brandenburg Airport  27/06/2024 23:00
# 1873         Madrid  Berlin Brandenburg Airport  27/06/2024 23:00
# 1874     Paris Orly  Berlin Brandenburg Airport  27/06/2024 23:10
# 1875  Fuerteventura  Berlin Brandenburg Airport  27/06/2024 23:25
#
#         Actual Arrival Terminal Baggage Claim Gate Flight Number  \
# 0     16/06/2024 06:03       T1            A4  N02        XQ 966
# 1     16/06/2024 07:11       T1            A3  X17        HU 489
# 2     16/06/2024 07:07       T1            A2  Y17        UA 962
# 3     16/06/2024 08:17       T1            A1  X01        5F 611
# 4     16/06/2024 07:21       T1            A4  X07        QR 079
# ...                ...      ...           ...  ...           ...
# 1871               NaN       T1            A4  A03        LX 962
# 1872               NaN       T2            C1  Z43       FR 1155
# 1873               NaN       T1            A3  A30       I2 3674
# 1874               NaN       T1            B4  N01       TO 3412
# 1875               NaN       T1            B3  S01       SR 3345
#
#          Aircraft Type Plane Reg Flight Status                Airline
# 0     737-800 Winglets     TCSUU       Arrived       Sun Express (XQ)
# 1             A330-300     B303C       Arrived   Hainan Airlines (HU)
# 2        767-400/400ER    N76062       Arrived   United Airlines (UA)
# 3     737-800 Winglets     URPSF       Arrived          Fly One (FIA)
# 4     787-9 Dreamliner     A7BHM       Arrived     Qatar Airways (QR)
# ...                ...       ...           ...                    ...
# 1871          A321-100     HBIOD     Scheduled             Swiss (LX)
# 1872         737 MAX 8     9HVUZ     Scheduled           Ryanair (FR)
# 1873          A321-100       NaN     Scheduled   IBERIA Express (IBS)
# 1874  737-800 Winglets       NaN     Scheduled  Transavia France (TO)
# 1875          A320-200     DASGK     Scheduled          SUNDAIR (SDR)
#
# [1876 rows x 12 columns]

# %%
df_arr3 = pd.read_excel('/Users/martynas/Desktop/Ironhack/Week 9:Selenium/Berlin Scraper/Data/arrival_info_18.xlsx')

# %%
df_arr3
# Out:
#                     Departure        Destination  Date and Time  \
# 0  Berlin Brandenburg Airport  Palma de Mallorca            NaN
# 1  Berlin Brandenburg Airport              Ibiza            NaN
# 2  Berlin Brandenburg Airport  Palma de Mallorca            NaN
# 3  Berlin Brandenburg Airport             Zurich            NaN
#
#    Actual Arrival  Terminal  Baggage Claim  Gate Flight Number  \
# 0             NaN       NaN            NaN   NaN       SR 2412
# 1             NaN       NaN            NaN   NaN       EW 8540
# 2             NaN       NaN            NaN   NaN       EJU5119
# 3             NaN       NaN            NaN   NaN       EJU5187
#
#         Aircraft Type Plane Reg Flight Status               Airline
# 0            A320-200     DASGK      Departed         SUNDAIR (SDR)
# 1            A321 neo     DAEEC      Departed        Eurowings (EW)
# 2  A320-200 Sharklets     OEIDU      Departed  easyJet Europe (EJU)
# 3                A319     OELKV      Departed  easyJet Europe (EJU)
