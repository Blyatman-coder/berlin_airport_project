# %%
import pandas as pd
from scipy.stats import norm
import matplotlib.pyplot as plt
import seaborn as sns

# data import - choose between arrivals or departures
cleaned_df = pd.read_csv('/Users/alexander/Work/Ironhack/Week12/Project/cleaned_arrivals_data.csv')

cleaned_df.sample(10)
# Out:
#          Departure Destination  Terminal Baggage Claim Gate Flight Number  \
# 1009         Basel      Berlin         1            A4  A30       EZS1189
# 1734     Frankfurt      Berlin         1            B3  B10        LH 200
# 3696     Amsterdam      Berlin         1            B3  B06       KL 1777
# 3371          Riga      Berlin         1            A4  A36        BT 211
# 4651     Paris CDG      Berlin         1            B1  Y02       AF 1834
# 4620    London STN      Berlin         2            C1  Z38        FR 145
# 319         Munich      Berlin         1            B2  B07       LH 1934
# 2621     Frankfurt      Berlin         1            B4  A06        LH 044
# 2440        Munich      Berlin         1            A4  A17       LH 1930
# 3971  Thessaloniki      Berlin         1            A3  A33        A3 512
#
#            Aircraft Type Plane Reg Flight Status  \
# 1009  A320-200 Sharklets     HBJXS       Arrived
# 1734            A320-200     DAIZG       Arrived
# 3696    737-800 Winglets     PHBCG       Arrived
# 3371            A220-300     YLABL       Arrived
# 4651            A321-200     FGTAJ       Arrived
# 4620    737-800 Winglets     9HQDE       Arrived
# 319   A320-200 Sharklets     DAIUB       Arrived
# 2621                A319     DAILI       Arrived
# 2440            A321-100     DAIRX       Arrived
# 3971  A320-200 Sharklets     SXDGZ       Arrived
#
#                             Airline        Date Scheduled Time  \
# 1009       easyJet Switzerland (DS)  2024-06-25       21:10:00
# 1734                 Lufthansa (LH)  2024-06-28       20:55:00
# 3696  KLM Royal Dutch Airlines (KL)  2024-07-13       13:45:00
# 3371                Air Baltic (BT)  2024-07-09       07:40:00
# 4651                Air France (AF)  2024-07-17       17:05:00
# 4620                   Ryanair (FR)  2024-07-17       14:30:00
# 319                  Lufthansa (LH)  2024-06-17       10:05:00
# 2621                 Lufthansa (LH)  2024-07-03       21:25:00
# 2440                 Lufthansa (LH)  2024-07-03       09:05:00
# 3971           Aegean Airlines (A3)  2024-07-14       16:50:00
#
#      Actual Arrival Time   Status  Time Difference (Minutes)  Temperature  \
# 1009            21:01:00    Early                         -9         25.0
# 1734            20:52:00    Early                         -3         23.8
# 3696            14:11:00  Delayed                         26         18.8
# 3371            07:43:00  Delayed                          3         28.8
# 4651            17:27:00  Delayed                         22         22.2
# 4620            14:24:00    Early                         -6         22.2
# 319             10:07:00  Delayed                          2         22.2
# 2621            22:10:00  Delayed                         45         16.0
# 2440            09:14:00  Delayed                          9         16.0
# 3971            17:17:00  Delayed                         27         22.7
#
#       Wind Speed     Type      Country
# 1009         9.4   budget  Switzerland
# 1734         9.8  premium      Germany
# 3696        10.3  premium  Netherlands
# 3371         8.1  premium       Latvia
# 4651        11.0  premium       France
# 4620        11.0   budget           UK
# 319          9.8  premium      Germany
# 2621         8.9  premium      Germany
# 2440         8.9  premium      Germany
# 3971         7.6  premium       Greece

# %%
# the number of flights per airline
flight_counts = cleaned_df['Airline'].value_counts()

# remove airlines with less than 10 flights
filtered_airlines = flight_counts[flight_counts >= 10].index
filtered_df = cleaned_df[cleaned_df['Airline'].isin(filtered_airlines)]

# one hot encoding on the status column
status_dummies = pd.get_dummies(filtered_df['Status'], prefix='Status')
filtered_df = pd.concat([filtered_df, status_dummies], axis=1)

# we only care about delayed because we are treating early and on time as the same

display(filtered_df)
# Out:
#               Departure Destination  Terminal Baggage Claim Gate  \
# 0             Izmir ADB      Berlin         1            A4  N02
# 1               Beijing      Berlin         1            A3  X17
# 2          New York EWR      Berlin         1            A2  Y17
# 4                  Doha      Berlin         1            A4  X07
# 5               Trieste      Berlin         2            C2  Z34
# ...                 ...         ...       ...           ...  ...
# 4749             Dublin      Berlin         2            C3  Z38
# 4750             Madrid      Berlin         1            A3  A38
# 4751         Paris Orly      Berlin         1            B2  N01
# 4752  Palma de Mallorca      Berlin         1            A3  A30
# 4753           Hurghada      Berlin         1            A4  N02
#
#      Flight Number     Aircraft Type Plane Reg Flight Status  \
# 0           XQ 966  737-800 Winglets     TCSUU       Arrived
# 1           HU 489          A330-300     B303C       Arrived
# 2           UA 962     767-400/400ER    N76062       Arrived
# 4           QR 079  787-9 Dreamliner     A7BHM       Arrived
# 5          FR 6781         737 MAX 8     9HVUF       Arrived
# ...            ...               ...       ...           ...
# 4749       FR 5418  737-800 Winglets     9HQCB       Arrived
# 4750       I2 3674          A321 neo     ECOAU       Arrived
# 4751       TO 3412  737-800 Winglets     FGZHC       Arrived
# 4752       EW 8593          A321-200     DAIDU       Arrived
# 4753       SR 6493          A320-200     DASMR       Arrived
#
#                     Airline  ... Actual Arrival Time   Status  \
# 0          Sun Express (XQ)  ...            06:03:00    Early
# 1      Hainan Airlines (HU)  ...            07:11:00  Delayed
# 2      United Airlines (UA)  ...            07:07:00    Early
# 4        Qatar Airways (QR)  ...            07:21:00  Delayed
# 5              Ryanair (FR)  ...            07:14:00    Early
# ...                     ...  ...                 ...      ...
# 4749           Ryanair (FR)  ...            22:57:00    Early
# 4750   IBERIA Express (IBS)  ...            22:47:00    Early
# 4751  Transavia France (TO)  ...            23:09:00    Early
# 4752         Eurowings (EW)  ...            23:51:00  Delayed
# 4753          SUNDAIR (SDR)  ...            23:07:00    Early
#
#      Time Difference (Minutes) Temperature  Wind Speed     Type  Country  \
# 0                          -27        23.8        10.5   budget   Turkey
# 1                           26        23.8        10.5  premium    China
# 2                           -8        23.8        10.5  premium      USA
# 4                            1        23.8        10.5  premium    Qatar
# 5                          -21        23.8        10.5   budget    Italy
# ...                        ...         ...         ...      ...      ...
# 4749                        -3        22.2        11.0   budget  Ireland
# 4750                       -13        22.2        11.0   budget    Spain
# 4751                        -1        22.2        11.0   budget   France
# 4752                        26        22.2        11.0   budget    Spain
# 4753                       -18        22.2        11.0   budget    Egypt
#
#      Status_Delayed Status_Early  Status_On-Time
# 0             False         True           False
# 1              True        False           False
# 2             False         True           False
# 4              True        False           False
# 5             False         True           False
# ...             ...          ...             ...
# 4749          False         True           False
# 4750          False         True           False
# 4751          False         True           False
# 4752           True        False           False
# 4753          False         True           False
#
# [4666 rows x 22 columns]

# %%
# calculate the total number of flights
budget_total = filtered_df[filtered_df['Type'] == 'budget'].shape[0]
premium_total = filtered_df[filtered_df['Type'] == 'premium'].shape[0]

# calculating the total number of ontime flights for both budget and premium
budget_ontime = filtered_df[(filtered_df['Type'] == 'budget') & (filtered_df['Status_Delayed'] == 0)].shape[0]
premium_ontime = filtered_df[(filtered_df['Type'] == 'premium') & (filtered_df['Status_Delayed'] == 0)].shape[0]

# calculate the sample proportion - budget
p_budget = budget_ontime / budget_total

# calculate the sample proportion - premium
p_premium = premium_ontime / premium_total

# SE budget
SE_budget = (p_budget * (1 - p_budget) / budget_total) ** 0.5

# SE premium
SE_premium = (p_premium * (1 - p_premium) / premium_total) ** 0.5

# set 95% CI
Z = norm.ppf(0.975)

# CI for budget
CI_budget_lower = p_budget - Z * SE_budget
CI_budget_upper = p_budget + Z * SE_budget

# CI for premium
CI_premium_lower = p_premium - Z * SE_premium
CI_premium_upper = p_premium + Z * SE_premium

print((p_budget, (CI_budget_lower, CI_budget_upper)), (p_premium, (CI_premium_lower, CI_premium_upper)))
print('For budget airlines we are 95% confident that the proportion of on time flights is between', CI_budget_lower, 'and', CI_budget_upper)
print('For premium airlines we are 95% confident that the proportion of on time flights is between', CI_premium_lower, 'and', CI_premium_upper)
# Out:
# (0.4898105112620665, (0.4712845111817415, 0.5083365113423914)) (0.5013376136971642, (0.4786696822497994, 0.5240055451445291))
# For budget airlines we are 95% confident that the proportion of on time flights is between 0.4712845111817415 and 0.5083365113423914
# For premium airlines we are 95% confident that the proportion of on time flights is between 0.4786696822497994 and 0.5240055451445291

# %%
# Let's check other data, starting with time:

filtered_df['Scheduled Time'] = pd.to_datetime(filtered_df['Scheduled Time'], format='%H:%M:%S').dt.time

# Seperating times into seperate 6 hour shifts (morning, afternoon and night)
def categorize_time_of_day(time):
    if time >= pd.to_datetime('06:00:00').time() and time < pd.to_datetime('12:00:00').time():
        return 'Morning'
    elif time >= pd.to_datetime('12:00:00').time() and time < pd.to_datetime('18:00:00').time():
        return 'Afternoon'
    elif time >= pd.to_datetime('18:00:00').time() and time < pd.to_datetime('23:59:59').time():
        return 'Evening'
        # weirdly, 00:00:00 doesn't work...
    else:
        return 'Late Night'
    
filtered_df['Time of Day'] = filtered_df['Scheduled Time'].apply(categorize_time_of_day)

filtered_df[['Scheduled Time', 'Time of Day']].sample(20)
# Out:
#      Scheduled Time Time of Day
# 2159       22:15:00     Evening
# 1348       10:25:00     Morning
# 2131       17:20:00   Afternoon
# 2477       11:25:00     Morning
# 4094       07:40:00     Morning
# 2234       10:50:00     Morning
# 4283       19:15:00     Evening
# 1794       09:35:00     Morning
# 3237       15:30:00   Afternoon
# 1522       07:20:00     Morning
# 2132       17:20:00   Afternoon
# 3429       11:15:00     Morning
# 1002       20:45:00     Evening
# 3749       18:05:00     Evening
# 3793       22:10:00     Evening
# 994        20:30:00     Evening
# 189        19:05:00     Evening
# 1951       22:15:00     Evening
# 3707       14:45:00   Afternoon
# 3942       14:50:00   Afternoon

# %%
# calculate number of morning/afternoon/night flights
time_total_flights = filtered_df['Time of Day'].value_counts()
time_delayed_flights = filtered_df[filtered_df['Status_Delayed'] == 1]['Time of Day'].value_counts()

# figure out the proportion
time_delay_proportion = time_delayed_flights / time_total_flights

# create a new DF
time_delay_df = pd.DataFrame({
    'Total Flights': time_total_flights,
    'Delayed Flights': time_delayed_flights,
    'Delay Proportion': time_delay_proportion
}).reset_index().rename(columns={'index': 'Time of Day'})

time_delay_df
# Out:
#   Time of Day  Total Flights  Delayed Flights  Delay Proportion
# 0   Afternoon           1619              927          0.572576
# 1     Evening           1587              981          0.618147
# 2  Late Night              7                6          0.857143
# 3     Morning           1453              445          0.306263

# %%
# Set up the matplotlib figure
plt.figure(figsize=(10, 6))

time_order = ['Morning', 'Afternoon', 'Evening', 'Night']
# To make sure the order is correct

sns.barplot(x='Time of Day', y='Delay Proportion', data=time_delay_df, order=time_order)

plt.xlabel('Time of Day')
plt.ylabel('Delay Proportion')
plt.title('Proportion of Delayed Flights by Time of Day')

plt.show()
# Out:
# /opt/anaconda3/envs/ironhack/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/anaconda3/envs/ironhack/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
# Leets check by airline:

airline_total_flights = filtered_df['Airline'].value_counts()
airline_delayed_flights = filtered_df[filtered_df['Status_Delayed'] == 1]['Airline'].value_counts()

# Calculate the proportion
airline_delay_proportion = airline_delayed_flights / airline_total_flights

# creat a new DF
airline_delay_df = pd.DataFrame({
    'Total Flights': airline_total_flights,
    'Delayed Flights': airline_delayed_flights,
    'Delay Chance': airline_delay_proportion
}).reset_index().rename(columns={'index': 'Airline'})

# airline_delay_df

airline_delay_df = airline_delay_df.sort_values(by='Delay Chance', ascending=False)

delay_summary_stats = airline_delay_df['Delay Chance'].describe()

print(delay_summary_stats)

display(airline_delay_df)
# Out:
# count    50.000000
# mean      0.440369
# std       0.180411
# min       0.120000
# 25%       0.280702
# 50%       0.461448
# 75%       0.547813
# max       0.833333
# Name: Delay Chance, dtype: float64
#                                   Airline  Total Flights  Delayed Flights  \
# 10                        Air Serbia (JU)             18               15
# 21                Freebird Airlines (FHY)             16               13
# 32                  Pegasus Airlines (PC)             98               75
# 39                             Swiss (LX)            140              103
# 42                  Turkish Airlines (TK)             83               56
# 2                                    (VF)             29               19
# 18                         Egypt Air (MS)             20               13
# 25          KLM Royal Dutch Airlines (KL)            125               77
# 3                    Aegean Airlines (A3)             39               23
# 5            Aero Services Executive (W4)             40               23
# 38                       Sun Express (XQ)            138               78
# 29                     Norwegian Air (D8)             38               21
# 34                           Ryanair (FR)            842              465
# 46                          Wizz Air (W6)             58               31
# 31                 Nouvelair Tunisie (BJ)             17                9
# 30             Norwegian Air Shuttle (DY)             51               27
# 27                         Lufthansa (LH)            437              229
# 6                         Air Baltic (BT)             44               23
# 19                         Eurowings (EW)            515              268
# 49                        easyJet UK (U2)             79               40
# 12                   British Airways (BA)            179               90
# 14                  Croatia Airlines (OU)             10                5
# 47                   easyJet Europe (EJU)            614              306
# 8                         Air France (AF)            105               51
# 35  SAS-Scandinavian Airlines System (SK)             73               34
# 40                  TAP Air Portugal (TP)             35               16
# 28                            Luxair (LG)             27               12
# 11                 Austrian Airlines (OS)            134               59
# 17            EL AL- Israel Airlines (LY)             24               10
# 13                 Brussels Airlines (SN)             54               22
# 41                  Transavia France (TO)             43               17
# 43                   United Airlines (UA)             18                7
# 44                 Volotea Airlines (VOE)             11                4
# 22                   Hainan Airlines (HU)             11                4
# 26               LOT Polish Airlines (LO)             41               13
# 9                          Air Malta (KM)             10                3
# 33                     Qatar Airways (QR)             38               11
# 48               easyJet Switzerland (DS)             18                5
# 0                                    (N0)             11                3
# 7                          Air Cairo (SM)             24                6
# 4                         Aer Lingus (EI)             24                6
# 20                           Finnair (AY)             73               17
# 37                             Scoot (TR)             14                3
# 45                  Vueling Airlines (VY)             47               10
# 36                          SUNDAIR (SDR)             66               14
# 23                   IBERIA Express (IBS)             56               11
# 15              Danish Air Transport (DX)             22                4
# 1                                    (OG)             12                2
# 16                   Delta Air Lines (DL)             20                3
# 24                        Icelandair (FI)             25                3
#
#     Delay Chance
# 10      0.833333
# 21      0.812500
# 32      0.765306
# 39      0.735714
# 42      0.674699
# 2       0.655172
# 18      0.650000
# 25      0.616000
# 3       0.589744
# 5       0.575000
# 38      0.565217
# 29      0.552632
# 34      0.552257
# 46      0.534483
# 31      0.529412
# 30      0.529412
# 27      0.524027
# 6       0.522727
# 19      0.520388
# 49      0.506329
# 12      0.502793
# 14      0.500000
# 47      0.498371
# 8       0.485714
# 35      0.465753
# 40      0.457143
# 28      0.444444
# 11      0.440299
# 17      0.416667
# 13      0.407407
# 41      0.395349
# 43      0.388889
# 44      0.363636
# 22      0.363636
# 26      0.317073
# 9       0.300000
# 33      0.289474
# 48      0.277778
# 0       0.272727
# 7       0.250000
# 4       0.250000
# 20      0.232877
# 37      0.214286
# 45      0.212766
# 36      0.212121
# 23      0.196429
# 15      0.181818
# 1       0.166667
# 16      0.150000
# 24      0.120000

# %%
# Let's examine the top10 by number of flights specifically - top10

top_airlines = airline_delay_df.nlargest(10, 'Total Flights')

plt.figure(figsize=(12, 8))

sns.barplot(x='Delay Chance', y='Airline', data=top_airlines.sort_values(by='Delay Chance', ascending=False))

# Add labels and title
plt.xlabel('Delay Chance')
plt.ylabel('Airline')
plt.title('Proportion of Delayed Flights by Top 10 Airlines')

# Show plot
plt.show()
# Out:
# /opt/anaconda3/envs/ironhack/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/anaconda3/envs/ironhack/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/anaconda3/envs/ironhack/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
# Let's examine the top10 by number of flights specifically top50

top_airlines_50 = airline_delay_df.nlargest(50, 'Total Flights')

plt.figure(figsize=(10, 8))

sns.barplot(x='Delay Chance', y='Airline', data=top_airlines_50.sort_values(by='Delay Chance', ascending=False))

# Add labels and title
plt.xlabel('Delay Chance')
plt.ylabel('Airline')
plt.title('Proportion of Delayed Flights by Top 50 Airlines')

# Show plot
plt.show()
# Out:
# /opt/anaconda3/envs/ironhack/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/anaconda3/envs/ironhack/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/anaconda3/envs/ironhack/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
